# %% [markdown]
# # Operators
# * Arthematic operator

# %%
a = 10
b = 20
print(a,b)
# Out:
# 10 20

# %%
print(a+b)
# Out:
# 30

# %%
print(a-b)
# Out:
# -10

# %%
print(a*b)
# Out:
# 200

# %%
print(a/b)
# Out:
# 0.5

# %%
print(a**b)
# Out:
# 100000000000000000000

# %%
print(b//a)
# Out:
# 2

# %%
print(b%a)
# Out:
# 0

# %% [markdown]
# # Assignment Operator

# %%
a = 22
b = 22
print(a,b)
# Out:
# 22 22

# %%
a = 2
a += 3
print(a)
# Out:
# 5

# %%
a -= 1
print(a)
# Out:
# 3

# %%
a *= 1
print(a)
# Out:
# 3

# %%
a **=2
print(a)
# Out:
# 81

# %%
a //= 3
print(a)
# Out:
# 9

# %%
a =9
a &= 4
print(a)
# Out:
# 0

# %%
a = 10
a &= 20
print(a)
# Out:
# 0

# %%
a = 2
a ^= 2
print(a)
# Out:
# 0

# %%
a = 2
a >>= 2
print(a)
# Out:
# 0

# %%
a = 8
a>>=1
print(a)
# Out:
# 4

# %%
a <<=1
print(a)
# Out:
# 16

# %% [markdown]
# # Bitwise

# %%
a = 10
b = 20
print(a&b)
# Out:
# 0

# %%
print(a|b)
# Out:
# 30

# %%
print(~a)
# Out:
# -11

# %%
print(a<<b)
# Out:
# 10485760

# %% [markdown]
# # Comparison Operator

# %%
a = 10
b = 20
print(a==b)
# Out:
# False

# %%
print(a!=b)
# Out:
# True

# %%
print(a<b)
# Out:
# True

# %%
print(a>b)
# Out:
# False

# %%
print(a<=b)
# Out:
# True

# %% [markdown]
# # Identity operator

# %%
a = 10
b = 20
print(a is b)
# Out:
# False

# %%
print(a is not b)
# Out:
# True

# %% [markdown]
# # Logical Operator

# %%
a = 10
b = 20
print(a==10 and b==20)
# Out:
# True

# %%
print(a==10 or b==20)
# Out:
# True

# %%
print(not(a==10 or b ==20))
# Out:
# False

# %% [markdown]
# # membership oprator

# %%
a = "deeepika"
b = "ika"
print(b in a)
# Out:
# True

# %%
print(b not in a)
# Out:
# False
