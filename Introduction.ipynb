# %% [markdown]
# # Python Programming
# # What is python
# * It is dynammic Programming Laguage = No need to declare the data type to a Variable
# * General Purpose Programming Language = we can use this language to create different applications
# * Spports Object oriented Programming = we can create objects and classes
# * Founctional Programming = Uses functions
# * Interpreted Language = executes the code line by line
# * High level programming language = Easy to understand
# # It was created by Guido van Rossum in 1989 , officially released in 1991.

# %% [markdown]
# #Features of Python
# * Python is simple and easy to understand.
# * It is interpreted and platform-independent, which makes debugging very easy.
# * Python is an open-source programming language.
# * Python provides extensive library support. Some of the popular libraries  include NumPy, TensorFlow, Selenium, OpenCV, etc.
# * It is possible to integrate other programming languages within Python.

# %% [markdown]
# #What is Python used for?
# * Python is used in data visualization to create plots and graphical representations.
# * Python helps in data analytics to analyze and understand raw data for insights and trends.
# *  It is used in AI and machine learning to simulate human behavior and to learn from past data without hard-coding.
# * It is used to create web applications.
# * It can be used to handle databases.
# * It is used in business and accounting to perform complex mathematical operations along with quantitative and qualitative analysis.

# %% [markdown]
# # What is Syntax
# * the syntax is the structural arrangement of comments, variables, numbers, operators, statements, loops, functions, classes, objects, etc., which helps us understand the meaning or semantics of a computer language.

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # Comments
# * To write a comment, just add a # at the start of the line

# %%
print("My Name is Deepika")
# Out:
# My Name is Deepika

# %%
n = 10;
if (n<11):
  print("True");
else:
  print("False")
# Out:
# True

# %%
n = 20;
i = 11;
if(n<30,i>10):
  print("True")
else:
  print("False")
# Out:
# True

# %% [markdown]
# # Variables
# * Variable names can only contain alphanumeric characters and underscores (A-Z, 0-9, and _).
# * Variable names must start with a letter or the underscore character.
# * Variables are case sensitive.
# * Variable names cannot start with a number.

# %%
a = "Deepika"
b = 1234
c = '_123'
print(a,b,c)
# Out:
# Deepika 1234 _123

# %%
_aa = "Deepika"
print(_aa)
# Out:
# Deepika

# %%
NameOfPerson="DEEPIKA REDDY"
print(NameOfPerson)
# Out:
# DEEPIKA REDDY

# %% [markdown]
# # Scope of Variables
# * LOCAL VARIABLES
# * A local variable is created within a function and can only be used inside that function. Such a variable has a local scope.

# %%
def person():
 age = 20
 name = 'deepika'
 sr_name = 'Chilukala'
 print(name + ' '+'is a good girl')
person()
# Out:
# deepika is a good girl

# %% [markdown]
# # GLOBAL VARIABLES
# * A global variable is created in the main body of the code and can be used anywhere within the code. Such a variable has a global scope.

# %%
a = 'Deepika'
def fruit():
  b = 'apple'
  c = 'mango'
  d = 'banana'
  print(d+''+' is a local variable')
  print(a+''+' is a global variable')
fruit()
# Out:
# banana is a local variable
# Deepika is a global variable
