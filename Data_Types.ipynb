# %% [markdown]
# # Data Convertion

# %%
a =  2
b = 22
c = 23
print(a,b,c)
# Out:
# 2 22 23

# %%
a = 2
b = float(a)
print(b)
# Out:
# 2.0

# %%
b = 2.33333333333
c =  int(b)
print(c)
# Out:
# 2

# %%
c = 2
d = complex(c)
print(d)
# Out:
# (2+0j)

# %%
c = 3
d = str(c)
print(d)
# Out:
# 3

# %%
type(d)
# Out:
# str

# %% [markdown]
# # Type Casting

# %%
str1 = "123"
str2 = "deepika"
num1 = 2
num2 = 90
print(float(num2))
print(complex(num2))
print(str(num2))
print(int(str1))
# Out:
# 90.0
# (90+0j)
# 90
# 123

# %%
type(num2)
# Out:
# int
